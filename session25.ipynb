# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px   #For inbuilt datasets

# %% [markdown]
# ### Why seaborn?
# - provides a layer of abstraction
# - better aesthetics
# - more graphs included
#
#       https://seaborn.pydata.org/api.html

# %% [markdown]
# ### Seaborn
#
# ##### Types of Functions
# - Figure Level
# - Axis Level
#
# ##### Main classification
# - Relational Plot
# - Distriutional Plot
# - Categorical Plot
# - Regression Plot
# - Matrix Plot
# - Multiplots

# %% [markdown]
# ### 1.Relational Plots
# - to see the statistical relation between 2 or more variables
# - Bivariate Analysis
#
# Plots under Relational Plots
# - LinePlot
# - ScatterPlot

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#scatter plot -> axes level function
sns.scatterplot(tips,x='total_bill',y='tip',hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# relplot -> figure level function
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',hue='sex',style='time',size='size')

# %%
# Facet Plot (relplot) : Works only with figure level function
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',row='smoker',col='sex',style='time',size='size')

# %%
gap = px.data.gapminder()
temp = gap[gap['country'] == "India"]
temp
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
# line plot -> axes level function
sns.lineplot(temp,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# relplot -> figure level function
sns.relplot(temp,x='year',y='lifeExp',kind='line')

# %%
temp_df = gap[gap['country'].isin(['India','Brazil','Germany'])]
temp_df
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
sns.lineplot(temp_df,x='year',y='lifeExp',hue='country',style='continent',size ='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(temp_df,x='year',y='lifeExp',hue='country',kind='line',style='continent',size ='continent')

# %%
# Facet plot
sns.relplot(temp_df,x='year',y='lifeExp',row='country',kind='line',style='continent',size ='continent')

# %% [markdown]
# ### 2.Distribution Plots
# - used to find out the distribution
# - Range of observation
# - Univariate Analysis
# - Central Tendency
# - Is the data bimodel?
# - Are there outliers?
#
# Plots under Relational Plots
# - HistPlot
# - RugPlot
# - kdeplot

# %%
#HistPlot
sns.histplot(tips,x='total_bill',bins=20,hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(tips,x='total_bill',kind='hist',bins=20,hue='sex',element='step')

# %%
sns.histplot(tips,x='day')
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
# Facet Function
sns.displot(tips,x='total_bill',kind='hist',bins=20,col='sex')

# %%
# kdeplot : Rather than using discrete bins, a kde plot smooths the observations with a Gaussian kernel, producing a continuous density estimate
sns.kdeplot(tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(tips,x='total_bill',kind='kde',hue='sex',fill=True)

# %%
#Rugplot
# Plot marginal distributions by drawing ticks along the x and y axes
# This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.
sns.kdeplot(tips,x='total_bill')
sns.rugplot(tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histplot
sns.histplot(tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(tips,x='total_bill',y='tip',kind='hist')

# %%
# Bivariate kdeplot
sns.kdeplot(tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(tips,x='total_bill',y='tip',kind='kde')

# %% [markdown]
# ### 3.Matrix Plots
#
# Plots under Relational Plots
# - Heatmap
# - Clustermap

# %%
temp_var = gap.pivot(index='country',columns='year',values='lifeExp')

# %%
plt.figure(figsize=(5,5))
sns.heatmap(temp_var)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
temporary = gap[gap['continent'] == 'Europe'].pivot(index='country',columns='year',values='lifeExp')
sns.heatmap(temporary, annot=True, linewidth=0.5, cmap='jet')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
iris = px.data.iris()

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])
